# %%
#cleaning data
#data.gov

import pandas as pd
from collections import OrderedDict
import re

# %%
df = pd.read_csv("D:/amazon_project/1429_1.csv",low_memory=False)
df
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#                          id  \
# 0      AVqkIhwDv8e3D1O-lebb
# 1      AVqkIhwDv8e3D1O-lebb
# 2      AVqkIhwDv8e3D1O-lebb
# 3      AVqkIhwDv8e3D1O-lebb
# 4      AVqkIhwDv8e3D1O-lebb
# ...                     ...
# 34651  AVpfiBlyLJeJML43-4Tp
# 34652  AVpfiBlyLJeJML43-4Tp
# 34653  AVpfiBlyLJeJML43-4Tp
# 34654  AVpfiBlyLJeJML43-4Tp
# 34655  AVpfiBlyLJeJML43-4Tp
#
#                                                     name       asins   brand  \
# 0      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  B01AHB9CN2  Amazon
# 1      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  B01AHB9CN2  Amazon
# 2      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  B01AHB9CN2  Amazon
# 3      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  B01AHB9CN2  Amazon
# 4      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  B01AHB9CN2  Amazon
# ...                                                  ...         ...     ...
# 34651                                                NaN  B006GWO5WK  Amazon
# ...

# %%
df.drop(['asins', 'keys', 'manufacturer', 'reviewsdateAdded', 'reviewsdidPurchase', 'reviewsdoRecommend', 'reviewsid', 'reviewsnumHelpful', 'reviewssourceURLs', 'reviewsuserCity', 'reviewsuserProvince', 'reviewsusername'], axis=1, inplace = True)  
df=df.dropna()
df
# Out:
#                          id  \
# 0      AVqkIhwDv8e3D1O-lebb
# 1      AVqkIhwDv8e3D1O-lebb
# 2      AVqkIhwDv8e3D1O-lebb
# 3      AVqkIhwDv8e3D1O-lebb
# 4      AVqkIhwDv8e3D1O-lebb
# ...                     ...
# 27892  AVpfl8cLLJeJML43AE3S
# 27893  AVpfl8cLLJeJML43AE3S
# 27894  AVpfl8cLLJeJML43AE3S
# 27895  AVpfl8cLLJeJML43AE3S
# 27896  AVpfl8cLLJeJML43AE3S
#
#                                                     name   brand  \
# 0      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 1      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 2      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 3      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 4      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# ...                                                  ...     ...
# 27892  New Amazon Kindle Fire Hd 9w Powerfast Adapter...  Amazon
# 27893  New Amazon Kindle Fire Hd 9w Powerfast Adapter...  Amazon
# ...

# %%
df
# Out:
#                          id  \
# 0      AVqkIhwDv8e3D1O-lebb
# 1      AVqkIhwDv8e3D1O-lebb
# 2      AVqkIhwDv8e3D1O-lebb
# 3      AVqkIhwDv8e3D1O-lebb
# 4      AVqkIhwDv8e3D1O-lebb
# ...                     ...
# 27892  AVpfl8cLLJeJML43AE3S
# 27893  AVpfl8cLLJeJML43AE3S
# 27894  AVpfl8cLLJeJML43AE3S
# 27895  AVpfl8cLLJeJML43AE3S
# 27896  AVpfl8cLLJeJML43AE3S
#
#                                                     name   brand  \
# 0      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 1      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 2      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 3      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 4      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# ...                                                  ...     ...
# 27892  New Amazon Kindle Fire Hd 9w Powerfast Adapter...  Amazon
# 27893  New Amazon Kindle Fire Hd 9w Powerfast Adapter...  Amazon
# ...

# %%
pd.options.mode.chained_assignment = None  # default='warn'
df['name']=df['name'].str.replace(","," ").astype(str)

# %%
df['name']
# Out:
# 0        All-New Fire HD 8 Tablet  8 HD Display  Wi-Fi ...
# 1        All-New Fire HD 8 Tablet  8 HD Display  Wi-Fi ...
# 2        All-New Fire HD 8 Tablet  8 HD Display  Wi-Fi ...
# 3        All-New Fire HD 8 Tablet  8 HD Display  Wi-Fi ...
# 4        All-New Fire HD 8 Tablet  8 HD Display  Wi-Fi ...
#                                ...
# 27892    New Amazon Kindle Fire Hd 9w Powerfast Adapter...
# 27893    New Amazon Kindle Fire Hd 9w Powerfast Adapter...
# 27894    New Amazon Kindle Fire Hd 9w Powerfast Adapter...
# 27895    New Amazon Kindle Fire Hd 9w Powerfast Adapter...
# 27896    New Amazon Kindle Fire Hd 9w Powerfast Adapter...
# Name: name, Length: 27841, dtype: object

# %%
## To remove dulpicate dta from same cloumn  


te mp=[]
for row in df['name']:
    s=row.splitlines()
    s=set(s)
    s=''.join(s)
    temp.append(s)
df['name']=pd.DataFrame(temp)
header=['name'] 
df=df.dropna()

##joining  two columns  reviews.text and reviews.title
# combine title and reviews.text column
df["comb_review"]=df[["reviewstitle","reviewstext"]].apply(lambda x:' '.join(x),axis=1)
df["comb_review"]
df.to_csv('Amamzon_Clean_data.csv') 
df
# Out:
#                          id  \
# 0      AVqkIhwDv8e3D1O-lebb
# 1      AVqkIhwDv8e3D1O-lebb
# 2      AVqkIhwDv8e3D1O-lebb
# 3      AVqkIhwDv8e3D1O-lebb
# 4      AVqkIhwDv8e3D1O-lebb
# ...                     ...
# 27836  AVpfl8cLLJeJML43AE3S
# 27837  AVpfl8cLLJeJML43AE3S
# 27838  AVpfl8cLLJeJML43AE3S
# 27839  AVpfl8cLLJeJML43AE3S
# 27840  AVpfl8cLLJeJML43AE3S
#
#                                                     name   brand  \
# 0      All-New Fire HD 8 Tablet  8 HD Display  Wi-Fi ...  Amazon
# 1      All-New Fire HD 8 Tablet  8 HD Display  Wi-Fi ...  Amazon
# 2      All-New Fire HD 8 Tablet  8 HD Display  Wi-Fi ...  Amazon
# 3      All-New Fire HD 8 Tablet  8 HD Display  Wi-Fi ...  Amazon
# 4      All-New Fire HD 8 Tablet  8 HD Display  Wi-Fi ...  Amazon
# ...                                                  ...     ...
# 27836  New Amazon Kindle Fire Hd 9w Powerfast Adapter...  Amazon
# 27837  New Amazon Kindle Fire Hd 9w Powerfast Adapter...  Amazon
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27785 entries, 0 to 27840
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               27785 non-null  object
#  1   name             27785 non-null  object
#  2   brand            27785 non-null  object
#  3   categories       27785 non-null  object
#  4   reviewsdate      27785 non-null  object
#  5   reviewsdateSeen  27785 non-null  object
#  6   reviewsrating    27785 non-null  float64
#  7   reviewstext      27785 non-null  object
#  8   reviewstitle     27785 non-null  object
#  9   comb_review      27785 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 2.3+ MB
# Index(['id', 'name', 'brand', 'categories', 'reviewsdate', 'reviewsdateSeen',
#        'reviewsrating', 'reviewstext', 'reviewstitle', 'comb_review'],
#       dtype='object')
